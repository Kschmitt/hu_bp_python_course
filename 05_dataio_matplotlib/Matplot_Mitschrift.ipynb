# %% [markdown]
# ##Mathplotlib

# %%
# %matplotlib inline
from pylab import *

# %%
xv=[1,2,3,4]; yv=[5,1,4,0]

# %%
plot(xv,yv)

# %%
plot(xv,yv,'ro')

# %%
myplot = plot(xv,yv,'k--')
setp(myplot, linewidth=3.0, marker='+', markersize=30)
# Out:
# [None, None, None]

# %%
axis()
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %%
axis( [0.5,4.5,-0.5,5.5] )
# Out:
# [0.5, 4.5, -0.5, 5.5]

# %%
ti = title('my own title')
xl=xlabel('time'); yl=ylabel('tomatoes')
setp(xl, fontweight ='bold')
# Out:
# [None]

# %%
savefig( 'foo.ps', dpi=600, format='ps', orientation='landscape' )

# %%
savefig( 'foo.ps', dpi=600, format='pdf', orientation='landscape' )

# %%
myfig=gcf()
close(myfig)

# %%
close('all')

# %%
fig2 = figure()
subplot(2,1,1)
plot( xv, yv, 'b-' )

subplot(2,1,2)
plot(yv,xv,'ro')

# %%
close(fig2)

# %%
fig2 = figure( figsize=(10,10) )
subplot(2,1,1)
plot( xv, yv, 'b-' )

subplot(2,1,2)
plot(yv,xv,'ro')

# %%
xv = np.arange(-10, 10.5, 0.5);  xv
# Out:
# array([-10. ,  -9.5,  -9. ,  -8.5,  -8. ,  -7.5,  -7. ,  -6.5,  -6. ,
#         -5.5,  -5. ,  -4.5,  -4. ,  -3.5,  -3. ,  -2.5,  -2. ,  -1.5,
#         -1. ,  -0.5,   0. ,   0.5,   1. ,   1.5,   2. ,   2.5,   3. ,
#          3.5,   4. ,   4.5,   5. ,   5.5,   6. ,   6.5,   7. ,   7.5,
#          8. ,   8.5,   9. ,   9.5,  10. ])

# %%
plot(xv, 2*xv**3-5*xv**2+7*xv)
plot(xv, 2000*cos(xv), 'r--')
text(-9.5,-2800,'curve A')
text(3,1500,'curve B')

# %%
close('all'); xv_lin=np.arange(-3,3.01,0.02)
xv = 10.**xv_lin
semilogx(xv, exp(-xv/0.01)+0.5*exp(-xv/10)+0.2*exp(-xv/200))

# %%
semilogx(xv, exp(-xv/0.01)+0.5*exp(-xv/10)+0.2*exp(-xv/200))
grid(color='k')

# %%
close('all')
xv=[0.5,1.5,2.5,3.5]; yv=[2,5,1,6]
mybar = bar(xv, yv, width=1, yerr=0.5)

# %%
mybar = bar(range(4), yv, width=1, yerr=0.5)

# %%
mybar = bar(range(4), yv, width=1, yerr=0.5)
xticks(xv, ['A','B','C','D'])
setp(mybar, color='r', edgecolor='k')
# Out:
# [None, None, None, None, None, None, None, None]

# %%
close('all')
figure(figsize=(5,5))
handles = pie( [1,2,3,4], explode = [0.2, 0, 0,0], shadow=True, labels=['A','B','C','D'] )
handles
# Out:
# ([<matplotlib.patches.Wedge at 0x7fdf4e8b0050>,
#   <matplotlib.patches.Wedge at 0x7fdf4e95ba90>,
#   <matplotlib.patches.Wedge at 0x7fdf4efe7d90>,
#   <matplotlib.patches.Wedge at 0x7fdf4e7f14d0>],
#  [<matplotlib.text.Text at 0x7fdf4e95b550>,
#   <matplotlib.text.Text at 0x7fdf4e95b410>,
#   <matplotlib.text.Text at 0x7fdf4e965210>,
#   <matplotlib.text.Text at 0x7fdf4e93ef50>])

# %%
figure(figsize=(5,5))
handles = pie( [1,2,3,4], explode = [0.2, 0, 0,0], shadow=True, labels=['A','B','C','D'] )
setp( handles[0] [0], color='y')
setp( handles[1] [0], text='lila stueck')
# Out:
# [None]

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
# %matplotlib
# Out:
# Using matplotlib backend: TkAgg

# %%
close('all')
fig=figure(); ax=Axes3D(fig)
import random as rn
xv=[]; yv=[]; zv=[]

for c in range(100):
    xv.append(rn.random()); yv.append(rn.random()); zv.append(rn.random())
    
ax.scatter(xv,yv,zv)

# %%
close('all')
fig=figure(); ax=Axes3D(fig)
xv=linspace(-10,10,100); yv=linspace(-10,10,100)

cx,cy=meshgrid(xv,yv)
cz=0.5*cx+exp(-cy**2)
tilt = ax.plot_surface(cx,cy,cz, linewidth=0, cmap=cm.jet)
style.use('grayscale')

# %%
style.available
# Out:
# [u'grayscale', u'bmh', u'dark_background', u'ggplot', u'fivethirtyeight']
